# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | torbay
# Processing Record 2 of Set 1 | yola
# Processing Record 3 of Set 1 | tagusao
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | burns lake
# Processing Record 6 of Set 1 | aykhal
# Processing Record 7 of Set 1 | abaza
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | binga
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | zaplyusye
# City not found. Skipping...
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | aurillac
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | kruisfontein
# Processing Record 18 of Set 1 | ostrovnoy
# Processing Record 19 of Set 1 | noumea
# Processing Record 20 of Set 1 | birao
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | rocha
# Processing Record 25 of Set 1 | macheng
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | mizan teferi
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | mount isa
# Processing Record 32 of Set 1 | sembe
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | sorland
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | hay river
# Processing Record 38 of Set 1 | vila velha
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | djambala
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | mumford
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | mayo
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | sibolga
# Processing Record 3 of Set 2 | flinders
# Processing Record 4 of Set 2 | naze
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | caravelas
# Processing Record 9 of Set 2 | port hardy
# Processing Record 10 of Set 2 | sao joao da barra
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | oussouye
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | gawler
# Processing Record 15 of Set 2 | tadine
# Processing Record 16 of Set 2 | guajara-mirim
# City not found. Skipping...
# Processing Record 17 of Set 2 | harper
# Processing Record 18 of Set 2 | half moon bay
# Processing Record 19 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 2 | algeciras
# Processing Record 23 of Set 2 | dicabisagan
# Processing Record 24 of Set 2 | faanui
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | saint-augustin
# Processing Record 28 of Set 2 | coruripe
# Processing Record 29 of Set 2 | tambopata
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | acarau
# Processing Record 32 of Set 2 | manaure
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | grants pass
# Processing Record 35 of Set 2 | pisco
# Processing Record 36 of Set 2 | sur
# Processing Record 37 of Set 2 | vardo
# Processing Record 38 of Set 2 | loandjili
# Processing Record 39 of Set 2 | fort nelson
# Processing Record 40 of Set 2 | cam ranh
# Processing Record 41 of Set 2 | vostok
# Processing Record 42 of Set 2 | airai
# Processing Record 43 of Set 2 | bousso
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | lagoa
# Processing Record 46 of Set 2 | cururupu
# Processing Record 47 of Set 2 | palembang
# Processing Record 48 of Set 2 | klaksvik
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | ushuaia
# Processing Record 1 of Set 3 | de panne
# Processing Record 2 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 3 | oranjemund
# Processing Record 4 of Set 3 | hamilton
# Processing Record 5 of Set 3 | marawi
# Processing Record 6 of Set 3 | jurm
# Processing Record 7 of Set 3 | aklavik
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | gopalpur
# Processing Record 10 of Set 3 | fortuna foothills
# Processing Record 11 of Set 3 | anadyr
# Processing Record 12 of Set 3 | rengo
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | pangnirtung
# Processing Record 15 of Set 3 | coronel bogado
# Processing Record 16 of Set 3 | new norfolk
# Processing Record 17 of Set 3 | iqaluit
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | umba
# Processing Record 21 of Set 3 | sao filipe
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | matara
# Processing Record 24 of Set 3 | chimoio
# Processing Record 25 of Set 3 | orthez
# Processing Record 26 of Set 3 | antalaha
# Processing Record 27 of Set 3 | sao paulo do potengi
# Processing Record 28 of Set 3 | kaitangata
# Processing Record 29 of Set 3 | arlit
# Processing Record 30 of Set 3 | hofn
# Processing Record 31 of Set 3 | silvan
# Processing Record 32 of Set 3 | svetlyy
# Processing Record 33 of Set 3 | santa maria
# Processing Record 34 of Set 3 | pyshma
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | hasaki
# Processing Record 37 of Set 3 | santa vitoria do palmar
# Processing Record 38 of Set 3 | valdivia
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | port elizabeth
# Processing Record 42 of Set 3 | tongren
# Processing Record 43 of Set 3 | bluff
# Processing Record 44 of Set 3 | sola
# Processing Record 45 of Set 3 | tommot
# Processing Record 46 of Set 3 | arraial do cabo
# Processing Record 47 of Set 3 | durban
# Processing Record 48 of Set 3 | katsuura
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | avarua
# Processing Record 1 of Set 4 | georgetown
# Processing Record 2 of Set 4 | barrow
# Processing Record 3 of Set 4 | la asuncion
# Processing Record 4 of Set 4 | milkovo
# Processing Record 5 of Set 4 | biltine
# Processing Record 6 of Set 4 | saint-joseph
# Processing Record 7 of Set 4 | samarai
# Processing Record 8 of Set 4 | el jicaro
# Processing Record 9 of Set 4 | bodden town
# Processing Record 10 of Set 4 | mariental
# Processing Record 11 of Set 4 | madang
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | melo
# Processing Record 14 of Set 4 | kirkland lake
# Processing Record 15 of Set 4 | mangan
# Processing Record 16 of Set 4 | husavik
# Processing Record 17 of Set 4 | boituva
# Processing Record 18 of Set 4 | kargasok
# Processing Record 19 of Set 4 | isetskoye
# Processing Record 20 of Set 4 | ondjiva
# Processing Record 21 of Set 4 | poltavka
# Processing Record 22 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 4 | ballina
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | isangel
# Processing Record 26 of Set 4 | ulladulla
# Processing Record 27 of Set 4 | tuktoyaktuk
# Processing Record 28 of Set 4 | charters towers
# Processing Record 29 of Set 4 | bontang
# Processing Record 30 of Set 4 | sale
# Processing Record 31 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 32 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | hamadan
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | lavrentiya
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | byron bay
# Processing Record 39 of Set 4 | marshall
# Processing Record 40 of Set 4 | boralday
# Processing Record 41 of Set 4 | tura
# Processing Record 42 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 4 | pochutla
# Processing Record 44 of Set 4 | ishigaki
# Processing Record 45 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 4 | atuona
# Processing Record 47 of Set 4 | sechura
# Processing Record 48 of Set 4 | guerrero negro
# Processing Record 49 of Set 4 | alghero
# Processing Record 50 of Set 4 | norheimsund
# Processing Record 1 of Set 5 | kavaratti
# Processing Record 2 of Set 5 | domoni
# Processing Record 3 of Set 5 | lukulu
# Processing Record 4 of Set 5 | mandalgovi
# Processing Record 5 of Set 5 | luderitz
# Processing Record 6 of Set 5 | irara
# Processing Record 7 of Set 5 | atambua
# Processing Record 8 of Set 5 | tahoua
# Processing Record 9 of Set 5 | taoudenni
# Processing Record 10 of Set 5 | russell
# Processing Record 11 of Set 5 | kloulklubed
# Processing Record 12 of Set 5 | puerto narino
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | tera
# Processing Record 15 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 16 of Set 5 | horia
# Processing Record 17 of Set 5 | serebryansk
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | yeppoon
# Processing Record 20 of Set 5 | kirakira
# Processing Record 21 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 5 | ende
# Processing Record 23 of Set 5 | nombre de dios
# Processing Record 24 of Set 5 | sao jose da coroa grande
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | inirida
# Processing Record 27 of Set 5 | shu
# Processing Record 28 of Set 5 | juneau
# Processing Record 29 of Set 5 | vrangel
# Processing Record 30 of Set 5 | tupelo
# Processing Record 31 of Set 5 | tuatapere
# Processing Record 32 of Set 5 | grand gaube
# Processing Record 33 of Set 5 | dneprovskaya
# Processing Record 34 of Set 5 | semey
# Processing Record 35 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 5 | solenzo
# Processing Record 37 of Set 5 | mar del plata
# Processing Record 38 of Set 5 | norman wells
# Processing Record 39 of Set 5 | leh
# Processing Record 40 of Set 5 | darnah
# Processing Record 41 of Set 5 | sioux lookout
# Processing Record 42 of Set 5 | kibala
# Processing Record 43 of Set 5 | zhanaozen
# Processing Record 44 of Set 5 | parry sound
# Processing Record 45 of Set 5 | porto novo
# Processing Record 46 of Set 5 | chokurdakh
# Processing Record 47 of Set 5 | evensk
# Processing Record 48 of Set 5 | baykit
# Processing Record 49 of Set 5 | sao miguel do araguaia
# Processing Record 50 of Set 5 | nanortalik
# Processing Record 1 of Set 6 | gweru
# Processing Record 2 of Set 6 | calvia
# Processing Record 3 of Set 6 | ukiah
# Processing Record 4 of Set 6 | palmer
# Processing Record 5 of Set 6 | fare
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | lata
# Processing Record 8 of Set 6 | fredericksburg
# Processing Record 9 of Set 6 | mogadishu
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | karratha
# Processing Record 12 of Set 6 | butaritari
# Processing Record 13 of Set 6 | mbuji-mayi
# Processing Record 14 of Set 6 | bud
# Processing Record 15 of Set 6 | hervey bay
# Processing Record 16 of Set 6 | zyryanka
# Processing Record 17 of Set 6 | partizanskoye
# Processing Record 18 of Set 6 | ponta do sol
# Processing Record 19 of Set 6 | vao
# Processing Record 20 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 6 | pangoa
# Processing Record 22 of Set 6 | poum
# Processing Record 23 of Set 6 | bathsheba
# Processing Record 24 of Set 6 | anshun
# Processing Record 25 of Set 6 | buala
# Processing Record 26 of Set 6 | port macquarie
# Processing Record 27 of Set 6 | belokurikha
# Processing Record 28 of Set 6 | slave lake
# Processing Record 29 of Set 6 | port augusta
# Processing Record 30 of Set 6 | saquarema
# Processing Record 31 of Set 6 | andra
# Processing Record 32 of Set 6 | chuy
# Processing Record 33 of Set 6 | bonavista
# Processing Record 34 of Set 6 | itaituba
# Processing Record 35 of Set 6 | aleksandrov gay
# Processing Record 36 of Set 6 | corowa
# Processing Record 37 of Set 6 | benton harbor
# Processing Record 38 of Set 6 | bilibino
# Processing Record 39 of Set 6 | tilichiki
# Processing Record 40 of Set 6 | salalah
# Processing Record 41 of Set 6 | presidente medici
# Processing Record 42 of Set 6 | stornoway
# Processing Record 43 of Set 6 | port blair
# Processing Record 44 of Set 6 | kodiak
# Processing Record 45 of Set 6 | klos
# Processing Record 46 of Set 6 | bahir dar
# Processing Record 47 of Set 6 | azangaro
# Processing Record 48 of Set 6 | bastia
# Processing Record 49 of Set 6 | ibra
# Processing Record 50 of Set 6 | songkhla
# Processing Record 1 of Set 7 | lompoc
# Processing Record 2 of Set 7 | itapaci
# Processing Record 3 of Set 7 | coihaique
# Processing Record 4 of Set 7 | broken hill
# Processing Record 5 of Set 7 | grand-lahou
# Processing Record 6 of Set 7 | okhotsk
# Processing Record 7 of Set 7 | bushenyi
# Processing Record 8 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 9 of Set 7 | mantua
# Processing Record 10 of Set 7 | kahului
# Processing Record 11 of Set 7 | north platte
# Processing Record 12 of Set 7 | sangar
# Processing Record 13 of Set 7 | sangre grande
# Processing Record 14 of Set 7 | wattegama
# Processing Record 15 of Set 7 | rawson
# Processing Record 16 of Set 7 | changying
# Processing Record 17 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 18 of Set 7 | cidreira
# Processing Record 19 of Set 7 | the pas
# Processing Record 20 of Set 7 | ilulissat
# Processing Record 21 of Set 7 | touros
# Processing Record 22 of Set 7 | prince rupert
# Processing Record 23 of Set 7 | shirokiy
# Processing Record 24 of Set 7 | buon me thuot
# City not found. Skipping...
# Processing Record 25 of Set 7 | bitkine
# Processing Record 26 of Set 7 | makakilo city
# Processing Record 27 of Set 7 | merate
# Processing Record 28 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 30 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 31 of Set 7 | viedma
# Processing Record 32 of Set 7 | padang
# Processing Record 33 of Set 7 | cap malheureux
# Processing Record 34 of Set 7 | constitucion
# Processing Record 35 of Set 7 | ziro
# Processing Record 36 of Set 7 | chapais
# Processing Record 37 of Set 7 | kavieng
# Processing Record 38 of Set 7 | tasiilaq
# Processing Record 39 of Set 7 | uvat
# Processing Record 40 of Set 7 | santa ines
# Processing Record 41 of Set 7 | buraydah
# Processing Record 42 of Set 7 | grand-santi
# Processing Record 43 of Set 7 | aden
# Processing Record 44 of Set 7 | kutum
# Processing Record 45 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 7 | lamar
# Processing Record 47 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 7 | bargur
# Processing Record 49 of Set 7 | puerto del rosario
# Processing Record 50 of Set 7 | codrington
# Processing Record 1 of Set 8 | camocim
# Processing Record 2 of Set 8 | qui nhon
# Processing Record 3 of Set 8 | burpengary
# Processing Record 4 of Set 8 | zavyalovo
# Processing Record 5 of Set 8 | cordoba
# Processing Record 6 of Set 8 | tibati
# Processing Record 7 of Set 8 | rorvik
# Processing Record 8 of Set 8 | nemuro
# Processing Record 9 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 10 of Set 8 | pandan
# Processing Record 11 of Set 8 | te anau
# Processing Record 12 of Set 8 | bridlington
# Processing Record 13 of Set 8 | zhirnov
# Processing Record 14 of Set 8 | ikryanoye
# Processing Record 15 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 16 of Set 8 | cherskiy
# Processing Record 17 of Set 8 | sal rei
# Processing Record 18 of Set 8 | los llanos de aridane
# Processing Record 19 of Set 8 | luganville
# Processing Record 20 of Set 8 | shache
# Processing Record 21 of Set 8 | vila franca do campo
# Processing Record 22 of Set 8 | clyde river
# Processing Record 23 of Set 8 | vicuna
# Processing Record 24 of Set 8 | nongan
# Processing Record 25 of Set 8 | kashi
# Processing Record 26 of Set 8 | sattahip
# Processing Record 27 of Set 8 | astana
# Processing Record 28 of Set 8 | bonthe
# Processing Record 29 of Set 8 | axim
# Processing Record 30 of Set 8 | smidovich
# Processing Record 31 of Set 8 | haines junction
# Processing Record 32 of Set 8 | jinxiang
# Processing Record 33 of Set 8 | yako
# Processing Record 34 of Set 8 | luanda
# Processing Record 35 of Set 8 | disna
# Processing Record 36 of Set 8 | san policarpo
# Processing Record 37 of Set 8 | qaqortoq
# Processing Record 38 of Set 8 | valparai
# Processing Record 39 of Set 8 | hami
# Processing Record 40 of Set 8 | olafsvik
# Processing Record 41 of Set 8 | tsabong
# Processing Record 42 of Set 8 | bansbaria
# Processing Record 43 of Set 8 | paramonga
# Processing Record 44 of Set 8 | jobner
# Processing Record 45 of Set 8 | port hedland
# Processing Record 46 of Set 8 | hohhot
# Processing Record 47 of Set 8 | lao cai
# Processing Record 48 of Set 8 | gladstone
# Processing Record 49 of Set 8 | mangrol
# Processing Record 50 of Set 8 | hobyo
# Processing Record 1 of Set 9 | nouadhibou
# Processing Record 2 of Set 9 | ejido
# Processing Record 3 of Set 9 | roald
# Processing Record 4 of Set 9 | corn island
# Processing Record 5 of Set 9 | chernyshkovskiy
# Processing Record 6 of Set 9 | middelburg
# Processing Record 7 of Set 9 | curuguaty
# Processing Record 8 of Set 9 | quelimane
# Processing Record 9 of Set 9 | port lincoln
# Processing Record 10 of Set 9 | liverpool
# Processing Record 11 of Set 9 | lambarene
# Processing Record 12 of Set 9 | buarcos
# Processing Record 13 of Set 9 | goodyear
# Processing Record 14 of Set 9 | ciorogarla
# Processing Record 15 of Set 9 | kangaatsiaq
# Processing Record 16 of Set 9 | west wendover
# Processing Record 17 of Set 9 | repnoye
# Processing Record 18 of Set 9 | meulaboh
# Processing Record 19 of Set 9 | tabou
# Processing Record 20 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 9 | selaphum
# Processing Record 23 of Set 9 | caucaia
# Processing Record 24 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 9 | strakonice
# Processing Record 27 of Set 9 | nouakchott
# Processing Record 28 of Set 9 | lingao
# Processing Record 29 of Set 9 | the valley
# Processing Record 30 of Set 9 | mahon
# Processing Record 31 of Set 9 | raudeberg
# Processing Record 32 of Set 9 | oktyabrskoye
# Processing Record 33 of Set 9 | araouane
# Processing Record 34 of Set 9 | barcelona
# Processing Record 35 of Set 9 | fairbanks
# Processing Record 36 of Set 9 | la ronge
# Processing Record 37 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 9 | mtimbira
# Processing Record 39 of Set 9 | xinzhou
# Processing Record 40 of Set 9 | berlevag
# Processing Record 41 of Set 9 | otta
# Processing Record 42 of Set 9 | naifaru
# Processing Record 43 of Set 9 | watertown
# Processing Record 44 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 9 | nizhniy tsasuchey
# Processing Record 47 of Set 9 | ulaangom
# Processing Record 48 of Set 9 | deputatskiy
# Processing Record 49 of Set 9 | peterhead
# Processing Record 50 of Set 9 | san quintin
# Processing Record 1 of Set 10 | balabac
# Processing Record 2 of Set 10 | namibe
# Processing Record 3 of Set 10 | beringovskiy
# Processing Record 4 of Set 10 | scarborough
# Processing Record 5 of Set 10 | inhambane
# Processing Record 6 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 10 | bar harbor
# Processing Record 8 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 9 of Set 10 | cockburn town
# Processing Record 10 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 11 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 12 of Set 10 | east london
# Processing Record 13 of Set 10 | marsh harbour
# Processing Record 14 of Set 10 | esil
# Processing Record 15 of Set 10 | udachnyy
# Processing Record 16 of Set 10 | burriana
# Processing Record 17 of Set 10 | socorro
# Processing Record 18 of Set 10 | wilmington
# Processing Record 19 of Set 10 | zhigansk
# Processing Record 20 of Set 10 | harlingen
# Processing Record 21 of Set 10 | guarapari
# Processing Record 22 of Set 10 | tokur
# Processing Record 23 of Set 10 | point pedro
# Processing Record 24 of Set 10 | arrecife
# Processing Record 25 of Set 10 | sitka
# Processing Record 26 of Set 10 | onufriyivka
# Processing Record 27 of Set 10 | markova
# Processing Record 28 of Set 10 | victoria
# Processing Record 29 of Set 10 | marietta
# Processing Record 30 of Set 10 | storslett
# Processing Record 31 of Set 10 | zlynka
# Processing Record 32 of Set 10 | bara
# Processing Record 33 of Set 10 | pimentel
# Processing Record 34 of Set 10 | ballinrobe
# Processing Record 35 of Set 10 | imbituba
# Processing Record 36 of Set 10 | solnechnyy
# Processing Record 37 of Set 10 | batemans bay
# Processing Record 38 of Set 10 | hurghada
# Processing Record 39 of Set 10 | sarkikaraagac
# Processing Record 40 of Set 10 | glarus
# Processing Record 41 of Set 10 | valdemarpils
# Processing Record 42 of Set 10 | edd
# Processing Record 43 of Set 10 | roma
# Processing Record 44 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 10 | general pico
# Processing Record 46 of Set 10 | lorengau
# Processing Record 47 of Set 10 | antofagasta
# Processing Record 48 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 49 of Set 10 | kaeo
# Processing Record 50 of Set 10 | metro
# Processing Record 1 of Set 11 | mattru
# Processing Record 2 of Set 11 | liapades
# City not found. Skipping...
# Processing Record 3 of Set 11 | kupang
# Processing Record 4 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 11 | monticello
# Processing Record 6 of Set 11 | prince george
# Processing Record 7 of Set 11 | cabo san lucas
# Processing Record 8 of Set 11 | grande prairie
# Processing Record 9 of Set 11 | chicama
# Processing Record 10 of Set 11 | tevriz
# Processing Record 11 of Set 11 | aksarka
# Processing Record 12 of Set 11 | alice town
# Processing Record 13 of Set 11 | korla
# Processing Record 14 of Set 11 | burica
# City not found. Skipping...
# Processing Record 15 of Set 11 | tuy hoa
# Processing Record 16 of Set 11 | kabare
# Processing Record 17 of Set 11 | olinda
# Processing Record 18 of Set 11 | kununurra
# Processing Record 19 of Set 11 | nome
# Processing Record 20 of Set 11 | kagal
# Processing Record 21 of Set 11 | freeport
# Processing Record 22 of Set 11 | mitu
# Processing Record 23 of Set 11 | cooma
# Processing Record 24 of Set 11 | pizarro
# Processing Record 25 of Set 11 | mount gambier
# Processing Record 26 of Set 11 | locri
# Processing Record 27 of Set 11 | ahipara
# Processing Record 28 of Set 11 | dunedin
# Processing Record 29 of Set 11 | praia
# Processing Record 30 of Set 11 | yantal
# Processing Record 31 of Set 11 | dalbandin
# Processing Record 32 of Set 11 | alexandria
# Processing Record 33 of Set 11 | najran
# Processing Record 34 of Set 11 | sulejowek
# Processing Record 35 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 36 of Set 11 | ouanaminthe
# Processing Record 37 of Set 11 | pitimbu
# Processing Record 38 of Set 11 | bay roberts
# Processing Record 39 of Set 11 | coleraine
# Processing Record 40 of Set 11 | svetlaya
# Processing Record 41 of Set 11 | necochea
# Processing Record 42 of Set 11 | okha
# Processing Record 43 of Set 11 | auki
# Processing Record 44 of Set 11 | gizo
# Processing Record 45 of Set 11 | ixtapa
# Processing Record 46 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 11 | nartan
# Processing Record 48 of Set 11 | illapel
# Processing Record 49 of Set 11 | polyarnyy
# Processing Record 50 of Set 11 | ashland
# Processing Record 1 of Set 12 | sarangani
# Processing Record 2 of Set 12 | santa rosa
# Processing Record 3 of Set 12 | arman
# Processing Record 4 of Set 12 | joensuu
# Processing Record 5 of Set 12 | fayetteville
# Processing Record 6 of Set 12 | letterkenny
# Processing Record 7 of Set 12 | nicoya
# Processing Record 8 of Set 12 | banda aceh
# Processing Record 9 of Set 12 | cerritos
# Processing Record 10 of Set 12 | tazovskiy
# Processing Record 11 of Set 12 | paracuru
# Processing Record 12 of Set 12 | poddorye
# Processing Record 13 of Set 12 | palmerston
# Processing Record 14 of Set 12 | santa eulalia
# Processing Record 15 of Set 12 | sarkand
# Processing Record 16 of Set 12 | opuwo
# Processing Record 17 of Set 12 | havre
# Processing Record 18 of Set 12 | sinnamary
# Processing Record 19 of Set 12 | adrar
# Processing Record 20 of Set 12 | never
# Processing Record 21 of Set 12 | florianopolis
# Processing Record 22 of Set 12 | haapiti
# Processing Record 23 of Set 12 | sayyan
# Processing Record 24 of Set 12 | brahmapuri
# City not found. Skipping...
# Processing Record 25 of Set 12 | comodoro rivadavia
# Processing Record 26 of Set 12 | zhezkazgan
# Processing Record 27 of Set 12 | herat
# Processing Record 28 of Set 12 | itacare
# Processing Record 29 of Set 12 | turukhansk
# Processing Record 30 of Set 12 | santa isabel do rio negro
# Processing Record 31 of Set 12 | muromtsevo
# Processing Record 32 of Set 12 | linxia
# Processing Record 33 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 12 | caruray
# Processing Record 35 of Set 12 | san jeronimo
# Processing Record 36 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 37 of Set 12 | fernie
# Processing Record 38 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 12 | beira
# Processing Record 40 of Set 12 | khandbari
# Processing Record 41 of Set 12 | miquelon
# Processing Record 42 of Set 12 | abong mbang
# Processing Record 43 of Set 12 | tezu
# Processing Record 44 of Set 12 | beloha
# Processing Record 45 of Set 12 | dosso
# Processing Record 46 of Set 12 | goderich
# Processing Record 47 of Set 12 | la palma
# Processing Record 48 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 12 | tateyama
# Processing Record 50 of Set 12 | casala-an
# Processing Record 1 of Set 13 | lisakovsk
# Processing Record 2 of Set 13 | singaparna
# Processing Record 3 of Set 13 | vigeland
# Processing Record 4 of Set 13 | leningradskiy
# Processing Record 5 of Set 13 | corinto
# Processing Record 6 of Set 13 | chato
# Processing Record 7 of Set 13 | nantucket
# Processing Record 8 of Set 13 | adre
# Processing Record 9 of Set 13 | dinar
# Processing Record 10 of Set 13 | abu dhabi
# Processing Record 11 of Set 13 | umm kaddadah
# Processing Record 12 of Set 13 | senneterre
# Processing Record 13 of Set 13 | okakarara
# Processing Record 14 of Set 13 | poro
# Processing Record 15 of Set 13 | yar-sale
# Processing Record 16 of Set 13 | qasigiannguit
# Processing Record 17 of Set 13 | mirpur sakro
# Processing Record 18 of Set 13 | sulangan
# Processing Record 19 of Set 13 | vogan
# Processing Record 20 of Set 13 | green river
# Processing Record 21 of Set 13 | lumut
# Processing Record 22 of Set 13 | itoman
# Processing Record 23 of Set 13 | richards bay
# Processing Record 24 of Set 13 | camacha
# Processing Record 25 of Set 13 | paamiut
# Processing Record 26 of Set 13 | kaniama
# Processing Record 27 of Set 13 | yulara
# Processing Record 28 of Set 13 | neiafu
# Processing Record 29 of Set 13 | goure
# Processing Record 30 of Set 13 | batesville
# Processing Record 31 of Set 13 | zenzeli
# Processing Record 32 of Set 13 | yulin
# Processing Record 33 of Set 13 | nikita
# Processing Record 34 of Set 13 | krasnoye
# Processing Record 35 of Set 13 | chumikan
# Processing Record 36 of Set 13 | colon
# Processing Record 37 of Set 13 | paeroa
# Processing Record 38 of Set 13 | jumla
# Processing Record 39 of Set 13 | karpathos
# Processing Record 40 of Set 13 | benguela
# Processing Record 41 of Set 13 | maturin
# Processing Record 42 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 43 of Set 13 | catamarca
# Processing Record 44 of Set 13 | gat
# Processing Record 45 of Set 13 | honningsvag
# Processing Record 46 of Set 13 | kapit
# Processing Record 47 of Set 13 | hokitika
# Processing Record 48 of Set 13 | uman
# Processing Record 49 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 50 of Set 13 | chistoye
# Processing Record 1 of Set 14 | bage
# Processing Record 2 of Set 14 | hambantota
# Processing Record 3 of Set 14 | bukama
# Processing Record 4 of Set 14 | muros
# Processing Record 5 of Set 14 | araguaina
# Processing Record 6 of Set 14 | horsham
# Processing Record 7 of Set 14 | orlik
# Processing Record 8 of Set 14 | sao felix do xingu
# Processing Record 9 of Set 14 | maner
# Processing Record 10 of Set 14 | yerofey pavlovich
# Processing Record 11 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 14 | santa cecilia
# Processing Record 13 of Set 14 | malibu
# Processing Record 14 of Set 14 | turbat
# Processing Record 15 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 14 | saint-pierre
# Processing Record 17 of Set 14 | athabasca
# Processing Record 18 of Set 14 | kaohsiung
# Processing Record 19 of Set 14 | thinadhoo
# Processing Record 20 of Set 14 | jalu
# Processing Record 21 of Set 14 | pueblo nuevo
# Processing Record 22 of Set 14 | mackay
# Processing Record 23 of Set 14 | pangai
# Processing Record 24 of Set 14 | xudat
# Processing Record 25 of Set 14 | noyabrsk
# Processing Record 26 of Set 14 | gobabis
# Processing Record 27 of Set 14 | shimoda
# Processing Record 28 of Set 14 | avera
# Processing Record 29 of Set 14 | minab
# Processing Record 30 of Set 14 | pacifica
# Processing Record 31 of Set 14 | hillsborough
# Processing Record 32 of Set 14 | batagay
# Processing Record 33 of Set 14 | katima mulilo
# Processing Record 34 of Set 14 | dong hoi
# Processing Record 35 of Set 14 | mayumba
# Processing Record 36 of Set 14 | kawalu
# Processing Record 37 of Set 14 | borger
# Processing Record 38 of Set 14 | honavar
# Processing Record 39 of Set 14 | cayenne
# Processing Record 40 of Set 14 | andenes
# Processing Record 41 of Set 14 | emba
# Processing Record 42 of Set 14 | aleksandrovskoye
# Processing Record 43 of Set 14 | omboue
# Processing Record 44 of Set 14 | tessalit
# Processing Record 45 of Set 14 | mackenzie
# Processing Record 46 of Set 14 | nekrasovka
# Processing Record 47 of Set 14 | khandyga
# Processing Record 48 of Set 14 | acapulco
# Processing Record 49 of Set 14 | srednekolymsk
# Processing Record 50 of Set 14 | kvitok
# Processing Record 1 of Set 15 | jutai
# Processing Record 2 of Set 15 | umm lajj
# Processing Record 3 of Set 15 | careiro da varzea
# Processing Record 4 of Set 15 | sabzevar
# Processing Record 5 of Set 15 | poronaysk
# Processing Record 6 of Set 15 | burgersdorp
# Processing Record 7 of Set 15 | nhulunbuy
# Processing Record 8 of Set 15 | gamba
# Processing Record 9 of Set 15 | gotha
# Processing Record 10 of Set 15 | mindelo
# Processing Record 11 of Set 15 | valentin gomez farias
# Processing Record 12 of Set 15 | yatou
# Processing Record 13 of Set 15 | iona
# Processing Record 14 of Set 15 | alice springs
# Processing Record 15 of Set 15 | omsukchan
# Processing Record 16 of Set 15 | kingsport
# Processing Record 17 of Set 15 | wa
# City not found. Skipping...
# Processing Record 18 of Set 15 | west bay
# Processing Record 19 of Set 15 | igarka
# Processing Record 20 of Set 15 | baherden
# Processing Record 21 of Set 15 | sokolo
# Processing Record 22 of Set 15 | puri
# Processing Record 23 of Set 15 | bemidji
# Processing Record 24 of Set 15 | rabo de peixe
# Processing Record 25 of Set 15 | trujillo
# Processing Record 26 of Set 15 | velizh
# Processing Record 27 of Set 15 | lethem
# Processing Record 28 of Set 15 | cabra
# Processing Record 29 of Set 15 | amga
# Processing Record 30 of Set 15 | miri
# Processing Record 31 of Set 15 | chinchani
# Processing Record 32 of Set 15 | novoagansk
# Processing Record 33 of Set 15 | lakhimpur
# Processing Record 34 of Set 15 | barranca
# Processing Record 35 of Set 15 | longyan
# Processing Record 36 of Set 15 | tempio pausania
# Processing Record 37 of Set 15 | road town
# Processing Record 38 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 39 of Set 15 | vanavara
# Processing Record 40 of Set 15 | lakeland highlands
# Processing Record 41 of Set 15 | akyab
# Processing Record 42 of Set 15 | alyangula
# Processing Record 43 of Set 15 | tatarastii de sus
# City not found. Skipping...
# Processing Record 44 of Set 15 | mulchen
# Processing Record 45 of Set 15 | sechelt
# Processing Record 46 of Set 15 | kombissiri
# Processing Record 47 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 48 of Set 15 | terney
# Processing Record 49 of Set 15 | zomin
# Processing Record 50 of Set 15 | shingu
# Processing Record 1 of Set 16 | margate
# Processing Record 2 of Set 16 | oktyabrskaya
# City not found. Skipping...
# Processing Record 3 of Set 16 | buluang
# Processing Record 4 of Set 16 | olga
# Processing Record 5 of Set 16 | nuuk
# Processing Record 6 of Set 16 | melilla
# Processing Record 7 of Set 16 | dingle
# Processing Record 8 of Set 16 | tucuman
# Processing Record 9 of Set 16 | copalau
# Processing Record 10 of Set 16 | bumba
# Processing Record 11 of Set 16 | erzin
# Processing Record 12 of Set 16 | san ramon de la nueva oran
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Torbay  47.6666  -52.7314     33.76        94         100       19.57
# 1        Yola   9.2000   12.4833     85.08        48          94        2.55
# 2     Tagusao   9.1924  117.8141     82.22        75         100        6.53
# 3   Cape Town -33.9258   18.4232     64.11        86           0       18.41
# 4  Burns Lake  54.2331 -125.7533     31.42        42         100        6.11
# 5      Aykhal  66.0000  111.5000     21.07        93          89       15.90
# 6       Abaza  52.6550   90.0928     28.44        64           2        3.67
# 7   Busselton -33.6500  115.3333     61.16        65           0        8.41
# 8       Binga -17.6203   27.3414     70.92        75          59        2.68
# 9    Hermanus -34.4187   19.2345     63.81        87         100        8.32
#
#   Country                 Date      Description
# 0      CA  2022-04-14 00:38:57             mist
# 1      NG  2022-04-14 00:38:57  overcast clouds
# 2      PH  2022-04-14 00:38:58  overcast clouds
# 3      ZA  2022-04-14 00:35:52        clear sky
# 4      CA  2022-04-14 00:38:58  overcast clouds
# 5      RU  2022-04-14 00:38:58  overcast clouds
# 6      RU  2022-04-14 00:38:59        clear sky
# 7      AU  2022-04-14 00:38:59        clear sky
# 8      ZW  2022-04-14 00:38:59    broken clouds
# 9      ZA  2022-04-14 00:39:00  overcast clouds

# %%
# Reorder the columns
city_data_df = city_data_df.rename(columns={"Description": "Current Description"})
new_column_order = ["City","Country","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed","Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#                            City Country      Lat       Lng  Max Temp  \
# 0                        Torbay      CA  47.6666  -52.7314     33.76
# 1                          Yola      NG   9.2000   12.4833     85.08
# 2                       Tagusao      PH   9.1924  117.8141     82.22
# 3                     Cape Town      ZA -33.9258   18.4232     64.11
# 4                    Burns Lake      CA  54.2331 -125.7533     31.42
# ..                          ...     ...      ...       ...       ...
# 692                     Tucuman      AR -26.8241  -65.2226     62.60
# 693                     Copalau      RO  47.6167   26.8333     49.96
# 694                       Bumba      CD   2.1833   22.4667     71.56
# 695                       Erzin      TR  36.9559   36.2000     46.17
# 696  San Ramon De La Nueva Oran      AR -23.1322  -64.3260     66.42
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          94         100       19.57                mist
# 1          48          94        2.55     overcast clouds
# 2          75         100        6.53     overcast clouds
# 3          86           0       18.41           clear sky
# 4          42         100        6.11     overcast clouds
# ..        ...         ...         ...                 ...
# 692        88         100        2.30     overcast clouds
# 693        58         100       10.47     overcast clouds
# 694        97         100        3.09     overcast clouds
# 695        39           0        4.70           clear sky
# 696        96         100        3.06     overcast clouds
#
# [697 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
